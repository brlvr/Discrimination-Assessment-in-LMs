# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from google.colab import userdata
GIT_USER = userdata.get('GIT_USER')
GIT_TOKEN = userdata.get('GIT_TOKEN')

# %%
# %cd /content/
# !git clone -b dev https://{GIT_TOKEN}@github.com/{GIT_USER}/Discrimination-Assessment-in-LMs
# Out:
# /content
# Cloning into 'Discrimination-Assessment-in-LMs'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 29 (delta 7), reused 26 (delta 7), pack-reused 0
# Receiving objects: 100% (29/29), 2.59 MiB | 12.01 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
# %cd /content/Discrimination-Assessment-in-LMs/
# Out:
# /content/Discrimination-Assessment-in-LMs

# %%
# !git checkout dev
# Out:
# Already on 'dev'
# Your branch is up to date with 'origin/dev'.

# %%
# %cp -r /content/drive/MyDrive/Colab Notebooks/DAiL.ipynb /content/Discrimination-Assessment-in-LMs/
# Out:
# cp: cannot stat '/content/drive/MyDrive/Colab': No such file or directory
# cp: cannot stat 'Notebooks/DAiL.ipynb': No such file or directory

# %%
# %cd /content
# !git addDAiL.ipynb
# Out:
# /content
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git merge origin/main
# Out:
# merge: main - not something we can merge
#
# Did you mean this?
# 	origin/main

# %%
# %cd /content/Discrimination-Assessment-in-LMs/
# !git fetch origin main
# !git checkout dev
# !git merge dev
# Out:
# /content/Discrimination-Assessment-in-LMs
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), 1.49 KiB | 1.49 MiB/s, done.
# From https://github.com/brlvr/Discrimination-Assessment-in-LMs
#  * branch            main       -> FETCH_HEAD
#    fb002f5..ee55e8d  main       -> origin/main
# Already on 'dev'
# Already up to date.

# %%
# !git merge main
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git checkout -b dev
# !git commit -m "Your commit message"
# !git push origin dev
# Out:
# fatal: A branch named 'dev' already exists.
# Enumerating objects: 26, done.
# Counting objects: 100% (26/26), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (14/14), done.
# Writing objects: 100% (26/26), 2.59 MiB | 5.14 MiB/s, done.
# Total 26 (delta 7), reused 26 (delta 7), pack-reused 0
# remote: Resolving deltas: 100% (7/7), done.
# remote:
# remote: Create a pull request for 'dev' on GitHub by visiting:
# remote:      https://github.com/brlvr/Discrimination-Assessment-in-LMs/pull/new/dev
# remote:
# To https://github.com/brlvr/Discrimination-Assessment-in-LMs
#  * [new branch]      dev -> dev

# %%
# !git config --global user.email GIT_MAIL
# !git config --global user.name GIT_USER

# %%
# !git add .

# %%
# !git commit -m "My Notebook!"
# Out:
# On branch dev
# nothing to commit, working tree clean

# %%
# !git remote add origin https://{GIT_USER}:{GIT_TOKEN}@github.com/{GIT_USER}/Discrimination-Assessment-in-LMs.git
# !git push -u origin main
# Out:
# error: remote origin already exists.
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# Everything up-to-date

# %%
?
